# %%
# %pip install tensorflow

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\astha\appdata\roaming\python\python313\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\astha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\astha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\astha\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8.2)
# Requirement already satisfied: pillow in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\astha\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\astha\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\astha\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\astha\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\astha\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.7 MB 3.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.7 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/8.7 MB 3.0 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.7 MB 2.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.1/8.7 MB 2.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.7/8.7 MB 2.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 4.7/8.7 MB 2.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.7 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.7 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.9/8.7 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 2.9 MB/s  0:00:02
# Downloading scipy-1.16.1-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.5/38.5 MB 46.9 kB/s eta 0:13:30
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#     --------------------------------------- 0.8/38.5 MB 69.0 kB/s eta 0:09:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
#    - -------------------------------------- 1.0/38.5 MB 88.0 kB/s eta 0:07:06
1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv('Customer_Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = dataset.drop(labels=['CustomerId', 'Surname','RowNumber', 'Exited'], axis=1)
y = dataset['Exited']

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label1=LabelEncoder()
X['Geography']=label1.fit_transform(X['Geography'])

# %%
X.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0  Female   42       2       0.00              1
# 1          608          2  Female   41       1   83807.86              1
# 2          502          0  Female   42       8  159660.80              3
# 3          699          0  Female   39       1       0.00              2
# 4          850          2  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
X['Gender']=label.fit_transform(X['Gender'])

# %%
X.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
X = pd.get_dummies(X, drop_first=True, columns=['Geography'])

# %%
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.24021723, -1.09665089,  0.77986083, ...,  1.64099027,
#         -0.57812007, -0.57504086],
#        [ 0.75974873,  0.91186722, -0.27382717, ..., -1.55587522,
#          1.72974448, -0.57504086],
#        [-1.72725557, -1.09665089, -0.9443559 , ...,  1.1038111 ,
#         -0.57812007, -0.57504086],
#        ...,
#        [-0.51484098,  0.91186722,  0.87565065, ..., -1.01507508,
#          1.72974448, -0.57504086],
#        [ 0.73902369, -1.09665089, -0.36961699, ..., -1.47887193,
#         -0.57812007, -0.57504086],
#        [ 0.95663657,  0.91186722, -1.32751517, ...,  0.50945854,
#         -0.57812007,  1.73900686]], shape=(8000, 11))

# %%
model = Sequential()
model.add(Dense(X.shape[1], activation='relu', input_dim=(X.shape[1])))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\astha\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
X.shape[1]
# Out:
# 11

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=10, verbose=1)
# Out:
# Epoch 1/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8176 - loss: 0.4420
# Epoch 2/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8434 - loss: 0.3784
# Epoch 3/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8524 - loss: 0.3597
# Epoch 4/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8553 - loss: 0.3517
# Epoch 5/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8575 - loss: 0.3461
# Epoch 6/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8609 - loss: 0.3405
# Epoch 7/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8627 - loss: 0.3383
# Epoch 8/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8608 - loss: 0.3352
# Epoch 9/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8630 - loss: 0.3341
# Epoch 10/10
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8644 - loss: 0.3318

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.16926168],
#        [0.14995502],
#        [0.02349779],
#        ...,
#        [0.02681935],
#        [0.9999843 ],
#        [0.07441701]], shape=(2000, 1), dtype=float32)

# %%
y_test
# Out:
# 1344    1
# 8167    0
# 4747    0
# 5004    1
# 3124    1
#        ..
# 9107    0
# 8249    0
# 8337    0
# 6279    1
# 412     0
# Name: Exited, Length: 2000, dtype: int64

# %%
model.evaluate(X_test, y_test.to_numpy())
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3461
# [0.3461112976074219, 0.8569999933242798]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y_test, (y_pred > 0.5).astype("int64"))
# Out:
# array([[1534,   59],
#        [ 227,  180]])

# %%
accuracy_score(y_test, (y_pred > 0.5).astype("int64"))
# Out:
# 0.857
